# %%
import pandas as pd
import numpy as np

# %%
df_train=pd.read_csv("/Users/Arpit/Desktop/DataSets/analytics_train.csv")

# %%
df_train.shape
# Out:
# (1628, 29)

# %%
df_train.head()
# Out:
#    Id  Age  Attrition BusinessTravel              Department  \
# 0   1   30          0     Non-Travel  Research & Development
# 1   2   36          0  Travel_Rarely  Research & Development
# 2   3   55          1  Travel_Rarely                   Sales
# 3   4   39          0  Travel_Rarely  Research & Development
# 4   5   37          0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 2          3        Medical             571
# 1                12          4  Life Sciences            1614
# 2                 2          1        Medical             842
# 3                24          1  Life Sciences            2014
# 4                 3          3          Other             689
#
#    EnvironmentSatisfaction  ... PerformanceRating  StockOptionLevel  \
# 0                        3  ...                 3                 0
# 1                        3  ...                 3                 2
# ...

# %%
df_test=pd.read_csv("/Users/Arpit/Desktop/DataSets/analytics_test.csv")

# %%
df_test.shape
# Out:
# (470, 28)

# %%
df_test.head()
# Out:
#    Id  Age BusinessTravel              Department  DistanceFromHome  \
# 0   1   28  Travel_Rarely  Research & Development                 9
# 1   2   31  Travel_Rarely                   Sales                 6
# 2   3   37  Travel_Rarely  Research & Development                 6
# 3   4   42  Travel_Rarely  Research & Development                 1
# 4   5   45     Non-Travel  Research & Development                 4
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          3        Medical             377                        4    Male
# 1          4        Medical             653                        1    Male
# 2          3        Medical             474                        3    Male
# 3          2  Life Sciences             827                        4  Female
# 4          2  Life Sciences             972                        3    Male
#
#    ...  PerformanceRating StockOptionLevel  TotalWorkingYears  \
# ...

# %%
df_train["Attrition"].value_counts()
# Out:
# 0    843
# 1    785
# Name: Attrition, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Arpit\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.scatterplot(x=df_train["Age"],y=df_train["Attrition"],data=df_train)

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df_train.corr(),annot=True)

# %%
sns.scatterplot(x=df_train["DistanceFromHome"],y=df_train["Attrition"],data=df_train)

# %%
df_train.info()
print("_"*50)
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628 entries, 0 to 1627
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       1628 non-null   int64
#  1   Age                      1628 non-null   int64
#  2   Attrition                1628 non-null   int64
#  3   BusinessTravel           1628 non-null   object
#  4   Department               1628 non-null   object
#  5   DistanceFromHome         1628 non-null   int64
#  6   Education                1628 non-null   int64
#  7   EducationField           1628 non-null   object
#  8   EmployeeNumber           1628 non-null   int64
#  9   EnvironmentSatisfaction  1628 non-null   int64
#  10  Gender                   1628 non-null   object
#  11  JobInvolvement           1628 non-null   int64
#  12  JobRole                  1628 non-null   object
#  13  JobSatisfaction          1628 non-null   int64
# ...

# %%
df_train.describe()
# Out:
#                 Id          Age    Attrition  DistanceFromHome    Education  \
# count  1628.000000  1628.000000  1628.000000       1628.000000  1628.000000
# mean    814.500000    35.645577     0.482187          9.735258     2.884521
# std     470.107435     9.481794     0.499836          8.306546     1.020470
# min       1.000000    18.000000     0.000000          1.000000     1.000000
# 25%     407.750000    29.000000     0.000000          2.000000     2.000000
# 50%     814.500000    34.000000     0.000000          8.000000     3.000000
# 75%    1221.250000    42.000000     1.000000         15.000000     4.000000
# max    1628.000000    60.000000     1.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  JobInvolvement  \
# count     1628.000000              1628.000000     1628.000000
# mean      1000.985872                 2.646192        2.650491
# std        585.417694                 1.125283        0.736330
# ...

# %%
df_train.describe(include="all")
# Out:
#                  Id          Age    Attrition BusinessTravel  \
# count   1628.000000  1628.000000  1628.000000           1628
# unique          NaN          NaN          NaN              3
# top             NaN          NaN          NaN  Travel_Rarely
# freq            NaN          NaN          NaN           1105
# mean     814.500000    35.645577     0.482187            NaN
# std      470.107435     9.481794     0.499836            NaN
# min        1.000000    18.000000     0.000000            NaN
# 25%      407.750000    29.000000     0.000000            NaN
# 50%      814.500000    34.000000     0.000000            NaN
# 75%     1221.250000    42.000000     1.000000            NaN
# max     1628.000000    60.000000     1.000000            NaN
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1628       1628.000000  1628.000000           1628
# ...

# %%
df_train["CommunicationSkill"].head()
# Out:
# 0    4
# 1    2
# 2    5
# 3    4
# 4    1
# Name: CommunicationSkill, dtype: int64

# %%
df_train[["CommunicationSkill","Attrition"]].groupby(["CommunicationSkill"],as_index=False).mean()
# Out:
#    CommunicationSkill  Attrition
# 0                   1   0.366300
# 1                   2   0.507692
# 2                   3   0.447284
# 3                   4   0.497076
# 4                   5   0.560000

# %%
df_train[["Gender","Attrition"]].groupby(["Gender"],as_index=False).mean()
# Out:
#    Gender  Attrition
# 0  Female   0.466772
# 1    Male   0.491968

# %%
data=df_train[["Age","Attrition"]].groupby(["Age"],as_index=False).mean()

# %%
plt.figure(figsize=(16,10))
sns.barplot(x=data["Age"],y=data["Attrition"],data=data)

# %%
d=df_train["Age"].value_counts(sort=False)
d.head()
# Out:
# 18    13
# 19    23
# 20    27
# 21    30
# 22    13
# Name: Age, dtype: int64

# %%
data=df_train[["TotalWorkingYears","Attrition"]].groupby(["TotalWorkingYears"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["TotalWorkingYears"],y=data["Attrition"],data=data)

# %%
data=df_train[["Education","Attrition"]].groupby(["Education"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["Education"],y=data["Attrition"],data=data)

# %%
data=df_train[["NumCompaniesWorked","Attrition"]].groupby(["NumCompaniesWorked"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["NumCompaniesWorked"],y=data["Attrition"],data=data)

# %%
df_train[["PerformanceRating","Attrition"]].groupby(["PerformanceRating"],as_index=False).mean()
# Out:
#    PerformanceRating  Attrition
# 0                  3   0.480000
# 1                  4   0.494071

# %%
#df_train.drop(["YearsSinceLastPromotion","PerformanceRating","PercentSalaryHike","EmployeeNumber"],axis=1,inplace=True)
#df_test.drop(["YearsSinceLastPromotion","PerformanceRating","PercentSalaryHike","EmployeeNumber"],axis=1)

# %%
df_train.shape
# Out:
# (1628, 29)

# %%
#df_test.drop(["YearsSinceLastPromotion","PerformanceRating","PercentSalaryHike","EmployeeNumber"],axis=1,inplace=True)

# %%
df_test.shape
# Out:
# (470, 28)

# %%
df_train.describe(include=["O"])
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            1628                    1628           1628   1628
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             1105                     979            623    996
#
#                 JobRole MaritalStatus OverTime
# count              1628          1628     1628
# unique                9             3        2
# top     Sales Executive       Married       No
# freq                365           681     1000

# %%
df_train[["BusinessTravel","Attrition"]].groupby(["BusinessTravel"],as_index=False).mean()
# Out:
#       BusinessTravel  Attrition
# 0         Non-Travel   0.291667
# 1  Travel_Frequently   0.632754
# 2      Travel_Rarely   0.447964

# %%
df_train[["Department","Attrition"]].groupby(["Department"],as_index=False).mean()
# Out:
#                Department  Attrition
# 0         Human Resources   0.555556
# 1  Research & Development   0.423902
# 2                   Sales   0.572183

# %%
df_train[["EducationField","Attrition"]].groupby(["EducationField"],as_index=False).mean()
# Out:
#      EducationField  Attrition
# 0   Human Resources   0.625000
# 1     Life Sciences   0.441413
# 2         Marketing   0.583756
# 3           Medical   0.451056
# 4             Other   0.411765
# 5  Technical Degree   0.617284

# %%
df_train[["Gender","Attrition"]].groupby(["Gender"],as_index=False).mean()
# Out:
#    Gender  Attrition
# 0  Female   0.466772
# 1    Male   0.491968

# %%
df_train["Gender"].value_counts()
# Out:
# Male      996
# Female    632
# Name: Gender, dtype: int64

# %%
df_train[["JobRole","Attrition"]].groupby(["JobRole"],as_index=False).mean()
# Out:
#                      JobRole  Attrition
# 0  Healthcare Representative   0.227273
# 1            Human Resources   0.625000
# 2      Laboratory Technician   0.580645
# 3                    Manager   0.222222
# 4     Manufacturing Director   0.247934
# 5          Research Director   0.000000
# 6         Research Scientist   0.483871
# 7            Sales Executive   0.506849
# 8       Sales Representative   0.784884

# %%
df_train[["MaritalStatus","Attrition"]].groupby(["MaritalStatus"],as_index=False).mean()
# Out:
#   MaritalStatus  Attrition
# 0      Divorced   0.394322
# 1       Married   0.389134
# 2        Single   0.626984

# %%
df_train[["OverTime","Attrition"]].groupby(["OverTime"],as_index=False).mean()
# Out:
#   OverTime  Attrition
# 0       No   0.355000
# 1      Yes   0.684713

# %%
#df_train.drop(["Department","Gender"],axis=1,inplace=True)
#df_test.drop(["Department","Gender"],axis=1,inplace=True)

# %%
df_train.describe(include=["O"])
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            1628                    1628           1628   1628
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             1105                     979            623    996
#
#                 JobRole MaritalStatus OverTime
# count              1628          1628     1628
# unique                9             3        2
# top     Sales Executive       Married       No
# freq                365           681     1000

# %%
df_train["Department"].value_counts()
# Out:
# Research & Development    979
# Sales                     568
# Human Resources            81
# Name: Department, dtype: int64

# %%
df_train[["Department","Attrition"]].groupby("Department",as_index=False).mean()
# Out:
#                Department  Attrition
# 0         Human Resources   0.555556
# 1  Research & Development   0.423902
# 2                   Sales   0.572183

# %%
mapping={"Research & Development":0,"Human Resources":1,"Sales":2}
df_train["Department"]=df_train["Department"].map(mapping)
df_test["Department"]=df_test["Department"].map(mapping)

# %%
mapping={"No":0,"Yes":1}
df_train["OverTime"]=df_train["OverTime"].map(mapping)

# %%
df_train["OverTime"].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: OverTime, dtype: int64

# %%
mapping={"Male":0,"Female":1}
df_test["Gender"]=df_test["Gender"].map(mapping)
df_train["Gender"]=df_train["Gender"].map(mapping)

# %%
mapping={"No":0,"Yes":1}
df_test["OverTime"]=df_test["OverTime"].map(mapping)

# %%
mapping={"Non-Travel":0,"Travel_Rarely":1,"Travel_Frequently":2}
df_train["BusinessTravel"]=df_train["BusinessTravel"].map(mapping)

# %%
mapping={"Non-Travel":0,"Travel_Rarely":1,"Travel_Frequently":2}
df_test["BusinessTravel"]=df_test["BusinessTravel"].map(mapping)

# %%
mapping={"Divorced":0,"Married":1,"Single":2}
df_train["MaritalStatus"]=df_train["MaritalStatus"].map(mapping)

# %%
mapping={"Divorced":0,"Married":1,"Single":2}
df_test["MaritalStatus"]=df_test["MaritalStatus"].map(mapping)

# %%
mapping={"Research Director":0,"Manager":1,"Healthcare Representative":2,"Manufacturing Director":3,"Research Scientist":4,"Sales Executive":5,"Laboratory Technician":6,"Human Resources":7,"Sales Representative":8}
df_test["JobRole"]=df_test["JobRole"].map(mapping)

# %%
df_train[["JobRole","Attrition"]].groupby(["JobRole"],as_index=False).mean()
# Out:
#                      JobRole  Attrition
# 0  Healthcare Representative   0.227273
# 1            Human Resources   0.625000
# 2      Laboratory Technician   0.580645
# 3                    Manager   0.222222
# 4     Manufacturing Director   0.247934
# 5          Research Director   0.000000
# 6         Research Scientist   0.483871
# 7            Sales Executive   0.506849
# 8       Sales Representative   0.784884

# %%
mapping={"Research Director":0,"Manager":1,"Healthcare Representative":2,"Manufacturing Director":3,"Research Scientist":4,"Sales Executive":5,"Laboratory Technician":6,"Human Resources":7,"Sales Representative":8}
df_train["JobRole"]=df_train["JobRole"].map(mapping)

# %%
df_train[["EducationField","Attrition"]].groupby(["EducationField"],as_index=False).mean()
# Out:
#      EducationField  Attrition
# 0   Human Resources   0.625000
# 1     Life Sciences   0.441413
# 2         Marketing   0.583756
# 3           Medical   0.451056
# 4             Other   0.411765
# 5  Technical Degree   0.617284

# %%
mapping={"Other":0,"Life Sciences":1,"Medical":2,"Marketing":3,"Technical Degree":4,"Human Resources":5}
df_train["EducationField"]=df_train["EducationField"].map(mapping)

# %%
mapping={"Other":0,"Life Sciences":1,"Medical":2,"Marketing":3,"Technical Degree":4,"Human Resources":5}
df_test["EducationField"]=df_test["EducationField"].map(mapping)

# %%
df_train.head()
# Out:
#    Id  Age  Attrition  BusinessTravel              Department  \
# 0   1   30          0               0  Research & Development
# 1   2   36          0               1  Research & Development
# 2   3   55          1               1                   Sales
# 3   4   39          0               1  Research & Development
# 4   5   37          0               1  Research & Development
#
#    DistanceFromHome  Education  EducationField  EmployeeNumber  \
# 0                 2          3               2             571
# 1                12          4               1            1614
# 2                 2          1               2             842
# 3                24          1               1            2014
# 4                 3          3               0             689
#
#    EnvironmentSatisfaction  ... PerformanceRating  StockOptionLevel  \
# 0                        3  ...                 3                 0
# 1                        3  ...                 3                 2
# ...

# %%
df_train.describe()
# Out:
#                 Id          Age    Attrition  BusinessTravel  \
# count  1628.000000  1628.000000  1628.000000     1628.000000
# mean    814.500000    35.645577     0.482187        1.173833
# std     470.107435     9.481794     0.499836        0.539643
# min       1.000000    18.000000     0.000000        0.000000
# 25%     407.750000    29.000000     0.000000        1.000000
# 50%     814.500000    34.000000     0.000000        1.000000
# 75%    1221.250000    42.000000     1.000000        1.000000
# max    1628.000000    60.000000     1.000000        2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeNumber  \
# count       1628.000000  1628.000000     1628.000000     1628.000000
# mean           9.735258     2.884521        1.906634     1000.985872
# std            8.306546     1.020470        1.150561      585.417694
# min            1.000000     1.000000        0.000000        1.000000
# ...

# %%
df_train.drop(["Id"],axis=1,inplace=True)

# %%
#df_test.drop(["Id"],axis=1,inplace=True)

# %%
df_train.info()
df_train.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628 entries, 0 to 1627
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1628 non-null   int64
#  1   Attrition                1628 non-null   int64
#  2   BusinessTravel           1628 non-null   int64
#  3   Department               1628 non-null   object
#  4   DistanceFromHome         1628 non-null   int64
#  5   Education                1628 non-null   int64
#  6   EducationField           1628 non-null   int64
#  7   EmployeeNumber           1628 non-null   int64
#  8   EnvironmentSatisfaction  1628 non-null   int64
#  9   Gender                   1628 non-null   object
#  10  JobInvolvement           1628 non-null   int64
#  11  JobRole                  1628 non-null   int64
#  12  JobSatisfaction          1628 non-null   int64
#  13  MaritalStatus            1628 non-null   int64
# ...

# %%
df_test.shape
# Out:
# (470, 28)

# %%
df_train.describe()
# Out:
#                Age    Attrition  BusinessTravel  DistanceFromHome  \
# count  1628.000000  1628.000000     1628.000000       1628.000000
# mean     35.645577     0.482187        1.173833          9.735258
# std       9.481794     0.499836        0.539643          8.306546
# min      18.000000     0.000000        0.000000          1.000000
# 25%      29.000000     0.000000        1.000000          2.000000
# 50%      34.000000     0.000000        1.000000          8.000000
# 75%      42.000000     1.000000        1.000000         15.000000
# max      60.000000     1.000000        2.000000         29.000000
#
#          Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# count  1628.000000     1628.000000     1628.000000              1628.000000
# mean      2.884521        1.906634     1000.985872                 2.646192
# std       1.020470        1.150561      585.417694                 1.125283
# ...

# %%
df_train[["Behaviour","Attrition"]].groupby(["Behaviour"],as_index=False).mean()
# Out:
#    Behaviour  Attrition
# 0          1   0.482187

# %%
#df_train.drop(["Behaviour"],axis=1,inplace=True)
#df_test.drop(["Behaviour"],axis=1,inplace=True)

# %%
df_train.shape
# Out:
# (1628, 28)

# %%
data=df_train[["Age","Attrition"]].groupby(["Age"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["Age"],y=data["Attrition"],data=data)

# %%
data=df_train[["DistanceFromHome","Attrition"]].groupby(["DistanceFromHome"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["DistanceFromHome"],y=data["Attrition"],data=data)

# %%
df_train[["MonthlyIncome","Attrition"]].groupby(["Attrition"],as_index=False).mean()
#plt.figure(figsize=(16,10))
#sns.barplot(x=data["MonthlyIncome"],y=data["Attrition"],data=data)
# Out:
#    Attrition  MonthlyIncome
# 0          0    6792.187426
# 1          1    4704.484076

# %%
df_train["MonthlyIncome"].describe()
# Out:
# count     1628.000000
# mean      5785.524570
# std       4339.293147
# min       1009.000000
# 25%       2625.000000
# 50%       4304.000000
# 75%       7124.250000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
data=df_train[["NumCompaniesWorked","Attrition"]].groupby(["NumCompaniesWorked"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["NumCompaniesWorked"],y=data["Attrition"],data=data)

# %%
data=df_train[["TotalWorkingYears","Attrition"]].groupby(["TotalWorkingYears"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["TotalWorkingYears"],y=data["Attrition"],data=data)

# %%
data=df_train[["YearsAtCompany","Attrition"]].groupby(["YearsAtCompany"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["YearsAtCompany"],y=data["Attrition"],data=data)

# %%
data=df_train[["YearsInCurrentRole","Attrition"]].groupby(["YearsInCurrentRole"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["YearsInCurrentRole"],y=data["Attrition"],data=data)

# %%
data=df_train[["YearsWithCurrManager","Attrition"]].groupby(["YearsWithCurrManager"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["YearsWithCurrManager"],y=data["Attrition"],data=data)

# %%
sns.boxplot(data=df_train["MonthlyIncome"])

# %%
sns.boxplot(data=df_train["TotalWorkingYears"])

# %%
sns.boxplot(data=df_train["YearsAtCompany"])

# %%
sns.boxplot(data=df_train["YearsWithCurrManager"])

# %%
sns.boxplot(data=df_train["YearsInCurrentRole"])

# %%
df_train["YearsInCurrentRole"].describe()
# Out:
# count    1628.000000
# mean        3.614865
# std         3.481051
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         7.000000
# max        18.000000
# Name: YearsInCurrentRole, dtype: float64

# %%
 df_train["DistanceFromHome"].hist(bins=)
# Out:
#   File "<ipython-input-79-d1a815406872>", line 1
#     df_train["DistanceFromHome"].hist(bins=)
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ###### df_train.head()

# %%
df_train[["DistanceFromHome","Attrition"]].groupby(["DistanceFromHome"],as_index=False).mean()

# %%
df_train.loc[(df_train["YearsWithCurrManager"]<=4),"YearsWithCurrManager"]=2
df_train.loc[(df_train["YearsWithCurrManager"]>4) & (df_train["YearsWithCurrManager"]<=9),"YearsWithCurrManager"]=1
df_train.loc[(df_train["YearsWithCurrManager"]>9) ,"YearsWithCurrManager"]=0
df_train[["YearsWithCurrManager","Attrition"]].groupby(["YearsWithCurrManager"],as_index=False).mean()

# %%
df_train.loc[(df_train["Age"]<=27),"Age"]=3
df_train.loc[(df_train["Age"]>27) & (df_train["Age"]<=37),"Age"]=2
df_train.loc[(df_train["Age"]>37) & (df_train["Age"]<=47),"Age"]=0
df_train.loc[(df_train["Age"]>47) ,"Age"]=1
df_train[["Age","Attrition"]].groupby(["Age"],as_index=False).mean()

# %%
df_train.head()

# %%
df_train["TotalWorkingYears"].describe()

# %%
sns.boxplot(data=df_train["TotalWorkingYears"])

# %%
data=df_train[["TotalWorkingYears","Attrition"]].groupby(["TotalWorkingYears"],as_index=False).mean()
plt.figure(figsize=(16,10))
sns.barplot(x=data["TotalWorkingYears"],y=data["Attrition"],data=data)

# %%
df_train.loc[(df_train["TotalWorkingYears"]<=8),"TotalWorkingYears"]=2
df_train.loc[(df_train["TotalWorkingYears"]>8) & (df_train["TotalWorkingYears"]<=17),"TotalWorkingYears"]=1
df_train.loc[(df_train["TotalWorkingYears"]>17) ,"TotalWorkingYears"]=0
df_train[["TotalWorkingYears","Attrition"]].groupby(["TotalWorkingYears"],as_index=False).mean()

# %%
df_train.loc[(df_train["YearsAtCompany"]<=10),"YearsAtCompany"]=1
df_train.loc[(df_train["YearsAtCompany"]>10) ,"YearsAtCompany"]=0
df_train[["YearsAtCompany","Attrition"]].groupby(["YearsAtCompany"],as_index=False).mean()

# %%
df_train.loc[(df_train["YearsInCurrentRole"]<=4),"YearsInCurrentRole"]=2
df_train.loc[(df_train["YearsInCurrentRole"]>4) & (df_train["YearsInCurrentRole"]<=9) ,"YearsInCurrentRole"]=1
df_train.loc[(df_train["YearsInCurrentRole"]>9) ,"YearsInCurrentRole"]=0
df_train[["YearsInCurrentRole","Attrition"]].groupby(["YearsInCurrentRole"],as_index=False).mean()

# %%
df_train.head()

# %%
df_train["MonthlyIncome"].describe()

# %%
df_train.loc[(df_train["MonthlyIncome"]<=5000),"MonthlyIncome"]=2
df_train.loc[(df_train["MonthlyIncome"]>5000) & (df_train["MonthlyIncome"]<=10000),"MonthlyIncome"]=1
df_train.loc[(df_train["MonthlyIncome"]>10000) ,"MonthlyIncome"]=0
df_train[["MonthlyIncome","Attrition"]].groupby(["MonthlyIncome"],as_index=False).mean()

# %%
df_train.head()

# %%
df_test.loc[(df_test["DistanceFromHome"]<=10),"DistanceFromHome"]=0
df_test.loc[(df_test["DistanceFromHome"]>10) & (df_test["DistanceFromHome"]<=20),"DistanceFromHome"]=1
df_test.loc[(df_test["DistanceFromHome"]>20) & (df_test["DistanceFromHome"]<=29) ,"DistanceFromHome"]=2

# %%
df_test.loc[(df_test["YearsWithCurrManager"]<=4),"YearsWithCurrManager"]=2
df_test.loc[(df_test["YearsWithCurrManager"]>4) & (df_test["YearsWithCurrManager"]<=9),"YearsWithCurrManager"]=1
df_test.loc[(df_test["YearsWithCurrManager"]>9) ,"YearsWithCurrManager"]=0

# %%
df_test.loc[(df_test["Age"]<=27),"Age"]=3
df_test.loc[(df_test["Age"]>27) & (df_test["Age"]<=37),"Age"]=2
df_test.loc[(df_test["Age"]>37) & (df_test["Age"]<=47),"Age"]=0
df_test.loc[(df_test["Age"]>47) ,"Age"]=1

# %%
df_test.loc[(df_test["TotalWorkingYears"]<=8),"TotalWorkingYears"]=2
df_test.loc[(df_test["TotalWorkingYears"]>8) & (df_test["TotalWorkingYears"]<=17),"TotalWorkingYears"]=1
df_test.loc[(df_test["TotalWorkingYears"]>17) ,"TotalWorkingYears"]=0

# %%
df_test.loc[(df_test["YearsAtCompany"]<=10),"YearsAtCompany"]=1
df_test.loc[(df_test["YearsAtCompany"]>10) ,"YearsAtCompany"]=0

# %%
df_test.loc[(df_test["YearsInCurrentRole"]<=4),"YearsInCurrentRole"]=2
df_test.loc[(df_test["YearsInCurrentRole"]>4) & (df_test["YearsInCurrentRole"]<=9) ,"YearsInCurrentRole"]=1
df_test.loc[(df_test["YearsInCurrentRole"]>9) ,"YearsInCurrentRole"]=0

# %%
df_test.loc[(df_test["MonthlyIncome"]<=5000),"MonthlyIncome"]=2
df_test.loc[(df_test["MonthlyIncome"]>5000) & (df_test["MonthlyIncome"]<=10000),"MonthlyIncome"]=1
df_test.loc[(df_test["MonthlyIncome"]>10000) ,"MonthlyIncome"]=0

# %%
df_test.head()
# Out:
#    Id  Age  BusinessTravel              Department  DistanceFromHome  \
# 0   1   28               1  Research & Development                 9
# 1   2   31               1                   Sales                 6
# 2   3   37               1  Research & Development                 6
# 3   4   42               1  Research & Development                 1
# 4   5   45               0  Research & Development                 4
#
#    Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          3               2             377                        4    Male
# 1          4               2             653                        1    Male
# 2          3               2             474                        3    Male
# 3          2               1             827                        4  Female
# 4          2               1             972                        3    Male
#
#    ...  PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
print(df_train.info())
print("_"*40)
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628 entries, 0 to 1627
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1628 non-null   int64
#  1   Attrition                1628 non-null   int64
#  2   BusinessTravel           1628 non-null   int64
#  3   Department               1628 non-null   int64
#  4   DistanceFromHome         1628 non-null   int64
#  5   Education                1628 non-null   int64
#  6   EducationField           1628 non-null   int64
#  7   EmployeeNumber           1628 non-null   int64
#  8   EnvironmentSatisfaction  1628 non-null   int64
#  9   Gender                   1628 non-null   int64
#  10  JobInvolvement           1628 non-null   int64
#  11  JobRole                  1628 non-null   int64
#  12  JobSatisfaction          1628 non-null   int64
#  13  MaritalStatus            1628 non-null   int64
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X_train=df_train[M]
Y_train=df_train["Attrition"]
X_test=df_test[M]

# %%
M=['Age','DistanceFromHome', 
       'EmployeeNumber',  'JobRole', 'JobSatisfaction', 
       'MonthlyIncome','OverTime',
       'PercentSalaryHike', 'StockOptionLevel',
       'TotalWorkingYears', 'YearsAtCompany',
       'YearsWithCurrManager']

# %%
N=["Attrition"]

# %%
from sklearn.feature_selection import RFE


#Recursive Feature Elimination (RFE)
model = RandomForestClassifier()

rfe = RFE(model, 10)
rfe = rfe.fit(df_train[M], df_train[N])
print(rfe.support_)
print(rfe.ranking_)
# Out:
# C:\Users\Arpit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:71: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# C:\Users\Arpit\Anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# C:\Users\Arpit\Anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y)
# ...

# %%
lg=LogisticRegression()
lg.fit(X_train,Y_train)
y_pred=lg.predict(X_test)
acc_log=round(lg.score(X_train,Y_train)*100,2)
acc_log
# Out:
# C:\Users\Arpit\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 76.23

# %%
import xgboost as xgb
xg_cl = xgb.XGBClassifier(objective='binary:logistic',
n_estimators=10, seed=123)
xg_cl.fit(X_train, Y_train)
preds = xg_cl.predict(X_test)
acc_xg = round(xg_cl.score(X_train, Y_train) * 100, 2)
acc_xg
# Out:
# 99.2

# %%
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc
# Out:
# 63.76

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn
# Out:
# 94.59

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree
# Out:
# 100.0

# %%
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc
# Out:
# C:\Users\Arpit\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 94.23

# %%
submission_analytics1=pd.DataFrame({"Id":df_test["Id"],"Attrition":Y_pred})

# %%
submission_analytics1
# Out:
#       Id  Attrition
# 0      1          0
# 1      2          0
# 2      3          0
# 3      4          0
# 4      5          0
# ..   ...        ...
# 465  466          0
# 466  467          1
# 467  468          0
# 468  469          0
# 469  470          0
#
# [470 rows x 2 columns]

# %%
submission_analytics1.to_csv(r'/Users/Arpit/Desktop/Submissions/submission_analytics1.csv',index=False)

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree
# Out:
# 100.0

# %%
submission_analytics2=pd.DataFrame({"Id":df_test["Id"],"Attrition":Y_pred})
submission_analytics2.to_csv(r'/Users/Arpit/Desktop/Submissions/submission_analytics2.csv',index=False)

# %%
lg=LogisticRegression()
lg.fit(X_train,Y_train)
y_pred=lg.predict(X_test)
acc_log=round(lg.score(X_train,Y_train)*100,2)
acc_log
submission_analytics3=pd.DataFrame({"Id":df_test["Id"],"Attrition":Y_pred})
submission_analytics3.to_csv(r'/Users/Arpit/Desktop/Submissions/submission_analytics3.csv',index=False)
# Out:
# C:\Users\Arpit\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
import xgboost as xgb
xg_cl = xgb.XGBClassifier(objective='binary:logistic',
n_estimators=10, seed=123)
xg_cl.fit(X_train, Y_train)
preds = xg_cl.predict(X_test)
acc_xg = round(xg_cl.score(X_train, Y_train) * 100, 2)
acc_xg
submission_analytics4=pd.DataFrame({"Id":df_test["Id"],"Attrition":Y_pred})
submission_analytics4.to_csv(r'/Users/Arpit/Desktop/Submissions/submission_analytics4.csv',index=False)

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn
submission_analytics5=pd.DataFrame({"Id":df_test["Id"],"Attrition":Y_pred})
submission_analytics5.to_csv(r'/Users/Arpit/Desktop/Submissions/submission_analytics5.csv',index=False)

# %% [raw]
# from sklearn.ensemble import RandomForestClassifier
# clf = RandomForestClassifier()
# clf.fit(X_train,Y_train)
# Y_pred = clf.predict_proba(X_test)
# acc_clf = round(clf.score(X_train, Y_train) * 100, 2)
# acc_clf
# submission_analytics6=pd.DataFrame({"Id":df_test["Id"],"Attrition":Y_pred})
# submission_analytics6.to_csv(r'/Users/Arpit/Desktop/Submissions/submission_analytics6.csv',index=False)

# %%
import xgboost as xgb
xg_cl = xgb.XGBClassifier(objective='binary:logistic',
random_state=2,)
xg_cl.fit(X_train, Y_train)
preds = xg_cl.predict(X_test)
acc_xg = round(xg_cl.score(X_train, Y_train) * 100, 2)
acc_xg
# Out:
# 100.0

# %%
submission_analytics6=pd.DataFrame({"Id":df_test["Id"],"Attrition":Y_pred})
submission_analytics6.to_csv(r'/Users/Arpit/Desktop/Submissions/submission_analytics6.csv',index=False)

# %%
df_train.corr()
# Out:
#                               Age  Attrition  BusinessTravel  \
# Age                      1.000000   0.213234        0.035066
# Attrition                0.213234   1.000000        0.190361
# BusinessTravel           0.035066   0.190361        1.000000
# DistanceFromHome        -0.044673   0.110183       -0.005809
# Education               -0.143278  -0.041390       -0.038304
# EducationField           0.074994   0.126425       -0.015420
# EnvironmentSatisfaction -0.001362  -0.111746       -0.022138
# JobInvolvement          -0.080656  -0.159710       -0.014059
# JobRole                  0.321104   0.343784        0.143311
# JobSatisfaction         -0.023347  -0.148012        0.031210
# MaritalStatus            0.146698   0.198327        0.024051
# MonthlyIncome            0.420596   0.210856        0.069440
# NumCompaniesWorked      -0.261388   0.034763       -0.047145
# OverTime                 0.012429   0.321194        0.051069
# ...

# %%
df_train
# Out:
#       Age  Attrition  BusinessTravel  DistanceFromHome  Education  \
# 0       2          0               0                 0          3
# 1       2          0               1                 1          4
# 2       1          1               1                 0          1
# 3       0          0               1                 2          1
# 4       2          0               1                 0          3
# ...   ...        ...             ...               ...        ...
# 1623    0          1               2                 1          3
# 1624    1          1               1                 0          1
# 1625    3          1               1                 0          2
# 1626    2          1               1                 1          3
# 1627    2          1               1                 1          1
#
#       EducationField  EnvironmentSatisfaction  JobInvolvement  JobRole  \
# 0                  2                        3               3        6
# ...

# %%
lg=LogisticRegression()
lg.fit(X_train,Y_train)
y_pred=lg.predict(X_test)
acc_log=round(lg.score(X_train,Y_train)*100,2)
acc_log
# Out:
# C:\Users\Arpit\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 77.52
